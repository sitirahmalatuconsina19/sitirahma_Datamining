# %% [markdown]
# <a href="https://colab.research.google.com/github/sitirahmalatuconsina19/sitirahma_Datamining/blob/main/AlgoritmaC45.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/jabodetabek_house_price.csv')
df
# Out:
#                                                     url   price_in_rp  \
# 0     https://www.rumah123.com/properti/bekasi/hos11...  2.990000e+09
# 1     https://www.rumah123.com/properti/bekasi/hos10...  1.270000e+09
# 2     https://www.rumah123.com/properti/bekasi/hos10...  1.950000e+09
# 3     https://www.rumah123.com/properti/bekasi/hos10...  3.300000e+09
# 4     https://www.rumah123.com/properti/bekasi/hos10...  4.500000e+09
# ...                                                 ...           ...
# 3548  https://www.rumah123.com/properti/tangerang/ho...  5.880000e+08
# 3549  https://www.rumah123.com/properti/tangerang/ho...  7.850000e+08
# 3550  https://www.rumah123.com/properti/tangerang/ho...  7.550000e+08
# 3551  https://www.rumah123.com/properti/tangerang/ho...  8.000000e+08
# 3552  https://www.rumah123.com/properti/tangerang/ho...  6.550000e+08
#
#                                                   title  \
# 0     Rumah cantik Sumarecon Bekasi\nLingkungan asri...
# ...

# %%
df.isnull().sum()
# Out:
# url                        0
# price_in_rp                0
# title                      0
# address                    0
# district                   0
# city                       0
# lat                        0
# long                       0
# facilities                 0
# property_type              1
# ads_id                     4
# bedrooms                  34
# bathrooms                 29
# land_size_m2               2
# building_size_m2           2
# carports                   0
# certificate              141
# electricity                0
# maid_bedrooms              0
# maid_bathrooms             0
# floors                     6
# building_age            1445
# year_built              1445
# property_condition       246
# building_orientation    1647
# garages                    0
# furnishing               387
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3553 entries, 0 to 3552
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   url                   3553 non-null   object
#  1   price_in_rp           3553 non-null   float64
#  2   title                 3553 non-null   object
#  3   address               3553 non-null   object
#  4   district              3553 non-null   object
#  5   city                  3553 non-null   object
#  6   lat                   3553 non-null   float64
#  7   long                  3553 non-null   float64
#  8   facilities            3553 non-null   object
#  9   property_type         3552 non-null   object
#  10  ads_id                3549 non-null   object
#  11  bedrooms              3519 non-null   float64
#  12  bathrooms             3524 non-null   float64
#  13  land_size_m2          3551 non-null   float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for column in df:
  if df[column].dtypes == object:
    df[column] = le.fit_transform(df[column])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3553 entries, 0 to 3552
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   url                   3553 non-null   int64
#  1   price_in_rp           3553 non-null   float64
#  2   title                 3553 non-null   int64
#  3   address               3553 non-null   int64
#  4   district              3553 non-null   int64
#  5   city                  3553 non-null   int64
#  6   lat                   3553 non-null   float64
#  7   long                  3553 non-null   float64
#  8   facilities            3553 non-null   int64
#  9   property_type         3553 non-null   int64
#  10  ads_id                3553 non-null   int64
#  11  bedrooms              3519 non-null   float64
#  12  bathrooms             3524 non-null   float64
#  13  land_size_m2          3551 non-null   float64
#  14  building_size_m2      3551 non-null   float64
# ...

# %%
df
# Out:
#        url   price_in_rp  title  address  district  city       lat  \
# 0      443  2.990000e+09   2841      355       343     0 -6.223945
# 1       48  1.270000e+09   1874      355       343     0 -6.223945
# 2       49  1.950000e+09   1581      355       343     0 -6.223945
# 3       73  3.300000e+09   1972      355       343     0 -6.223945
# 4       57  4.500000e+09   1836      355       343     0 -6.223945
# ...    ...           ...    ...      ...       ...   ...       ...
# 3548  3331  5.880000e+08   3236      197       189     8 -6.296615
# 3549  3300  7.850000e+08   2181      242       231     8 -6.283454
# 3550  3298  7.550000e+08   2026      242       231     8 -6.283454
# 3551  3292  8.000000e+08   1047       20        21     8 -6.288237
# 3552  3286  6.550000e+08   1063      349       338     8 -6.296963
#
#             long  facilities  property_type  ...  electricity  maid_bedrooms  \
# 0     106.986275        1836              0  ...           18            0.0
# ...

# %%
df.describe()
# Out:
#                url   price_in_rp        title      address     district  \
# count  3553.000000  3.553000e+03  3553.000000  3553.000000  3553.000000
# mean   1775.764143  4.191685e+09  1673.018576   185.258373   177.927667
# std    1025.494912  1.375067e+10   970.625873   116.893129   113.203213
# min       0.000000  4.200000e+07     0.000000     0.000000     0.000000
# 25%     888.000000  8.000000e+08   828.000000    89.000000    86.000000
# 50%    1776.000000  1.500000e+09  1673.000000   171.000000   164.000000
# 75%    2664.000000  3.590000e+09  2515.000000   293.000000   282.000000
# max    3551.000000  5.800000e+11  3341.000000   396.000000   379.000000
#
#               city          lat         long   facilities  property_type  ...  \
# count  3553.000000  3553.000000  3553.000000  3553.000000    3553.000000  ...
# mean      3.431185    -6.324721   106.792881  1080.590768       0.000281  ...
# std       3.088021     0.129245     0.172159   529.193991       0.016777  ...
# ...

# %%
df = df.drop(['url'], axis=1)

# %%
x = df.drop(['property_type'], axis=1)
y = df['property_type']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=500, max_depth=None,
                               min_samples_split=2,
                               min_samples_leaf=1,
                               min_weight_fraction_leaf=0,
                               max_leaf_nodes=None,
                               min_impurity_decrease=0)

# %%
clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-e8cc7e3e3ae6> in <cell line: 1>()
# ----> 1 clf.predict(x_test)
#
# NameError: name 'clf' is not defined

# %%
model.score(x_test, y_test)
# Out:
# 0.7769816390506046

# %%
from sklearn.tree import export_graphviz
import graphviz

tree_data = export_graphviz(model, out_file = None,
                                feature_names = x.columns,
                                class_names = ['0','1'],
                                filled = True)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-20-7535ac04bcf7> in <cell line: 4>()
#       2 import graphviz
#       3
# ----> 4 tree_data = export_graphviz(model, out_file = None,
#       5                                 feature_names = x.columns,
#       6                                 class_names = ['0','1'],
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     857     """
#     858
# --> 859     check_is_fitted(decision_tree)
#     860     own_file = False
#     861     return_string = False
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1388
# ...

# %%
graph = graphviz.Source(tree.data)
graph.view
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-55eb1b744044> in <cell line: 1>()
# ----> 1 graph = graphviz.Source(tree.data)
#       2 graph.view
#
# NameError: name 'tree' is not defined

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

#Confusion Matrix
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test,y_pred)
print("CONFUSION MATRIX")
print(cm)
akurasi=classification_report(y_test,y_pred)
print("ACCURACY C4.5")
print("Accuracy :", akurasi)
akurasi=accuracy_score(y_test,y_pred)
print('Tingkat akurasi : {:.2%}'.format(akurasi))
# Out:
# CONFUSION MATRIX
# [[937 245]
#  [253 798]]
# ACCURACY C4.5
# Accuracy :               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79      1182
#            1       0.77      0.76      0.76      1051
#
#     accuracy                           0.78      2233
#    macro avg       0.78      0.78      0.78      2233
# weighted avg       0.78      0.78      0.78      2233
#
# Tingkat akurasi : 77.70%
